# %% [markdown]
# <a href="https://colab.research.google.com/github/RezSat/synthetic-data-generator/blob/main/train_layoutlmv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone
